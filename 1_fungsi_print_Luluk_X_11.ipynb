# %% [markdown]
# <a href="https://colab.research.google.com/github/lulukrifah18/KKA-X-Semester-1/blob/main/1_fungsi_print_Luluk_X_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Luklukur Rif'ah
#
# Kelas:X.11
#
# No.Absen:18

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print("Luklukur Rif'ah")
# Out:
# Luklukur Rif'ah

# %% [markdown]
# #Menampilkan nama variabel

# %%
nama_saudara="Wihda syafirna"
print("Wihda syafirna")
# Out:
# Wihda syafirna

# %%
jumlah_saudara=2
print(2)
# Out:
# 2

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel

# %% [markdown]
# #Menampilkan Teks Bebas Menggunakan Tanda Koma

# %%
print("saya memiliki saudara sebanyak",jumlah_saudara,"nama saudara Saya adalah",nama_saudara)
# Out:
# saya memiliki saudara sebanyak 2 nama saudara Saya adalah Wihda syafirna

# %% [markdown]
# ##Menampilkan Teks Bebas dan Nilai Variabel Menggunakan tanda plus

# %%
print("saya memiliki saudara sebanyak " + str(jumlah_saudara) + ". "+"Nama saudara saya adalah " + nama_saudara + ".")
# Out:
# saya memiliki saudara sebanyak 2. Nama saudara saya adalah Wihda syafirna.

# %% [markdown]
# ##Menampilkan Teks Bebas dan Nilai Variabel Menggunakan Tanda f string

# %%
print(f"saya memiliki saudara sebanyak {jumlah_saudara}. Nama saudara saya adalah {nama_saudara}.")
# Out:
# saya memiliki saudara sebanyak 2. Nama saudara saya adalah Wihda syafirna.

# %% [markdown]
# ##Escape Character

# %%
print("Nama: Luklukur Rif'ah")
print("kelas:X.11")
print("No.Absen:18")
# Out:
# Nama: Luklukur Rif'ah
# kelas:X.11
# No.Absen:18

# %%
print("Nama: Luklukur Rif'ah\nKelas:X.11\nNo.Absen:18")
# Out:
# Nama: Luklukur Rif'ah
# Kelas:X.11
# No.Absen:18

# %%
print("""Nama\t\t: Luklukur Rif'ah
Kelas\t\t:X.11
No.Absen\t:18""")
# Out:
# Nama		: Luklukur Rif'ah
# Kelas		:X.11
# No.Absen	:18

# %%
print("Luklukur Rif'ah")
# Out:
# Luklukur Rif'ah

# %%
print('Luklukur Rifah')
# Out:
# Luklukur Rifah

# %% [markdown]
# #Fungsi Parameter

# %%
nama_siswa_1="Daffanes"
nama_siswa_2="Adzka"
nama_siswa_3="Haidar"

print(nama_siswa_1, nama_siswa_2, sep="-")
# Out:
# Daffanes-Adzka

# %%
nama_siswa_1="Daffanes"
nama_siswa_2="Adzka"
nama_siswa_3="Haidar"
print(nama_siswa_1, nama_siswa_2,sep="-")
# Out:
# Daffanes-Adzka

# %%
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Daffanes
# Adzka

# %%
print(nama_siswa_1, nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_1,end="-")
print(nama_siswa_2)
# Out:
# Daffanes-Adzka

# %% [markdown]
# #Latihan soal:
#  gunakan parameter end untuk menampilkan tulisan sebagai
#  berikut:
# Haidar#Adzka#Daffanes#Adzka

# %%
print(nama_siswa_3,end="-")
print(nama_siswa_2,end="-")
print(nama_siswa_1,end="-")
print(nama_siswa_2,end="-")
# Out:
# Haidar-Adzka-Daffanes-Adzka-
