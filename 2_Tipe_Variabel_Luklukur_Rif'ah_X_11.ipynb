# %% [markdown]
# <a href="https://colab.research.google.com/github/lulukrifah18/KKA-X-Semester-1/blob/main/2_Tipe_Variabel_Luklukur_Rif'ah_X_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama    : Luklukur Rif'ah
#
# kelas   : X.11
#
# no.absen: 18

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("LuklukurRif'ah.2025@gmail.com")
print("LuklukurRif'ah.2025@gmail.com")
print("LuklukurRif'ah.2025@gmail.com")
# Out:
# LuklukurRif'ah.2025@gmail.com
# LuklukurRif'ah.2025@gmail.com
# LuklukurRif'ah.2025@gmail.com

# %%
email_user_1 = "Luklukur Rif'ah.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# Luklukur Rif'ah.2025@gmail.com
# Luklukur Rif'ah.2025@gmail.com
# Luklukur Rif'ah.2025@gmail.com

# %% [markdown]
# #Peraturan Penamaan Variabel

# %%
#hanya diperbolehkan menggunakan huruf,angka,dan underscore
email user 2 = "Luluk@gmail.com"

print(email_user_2)
# Out:
#   File "/tmp/ipython-input-1063126682.py", line 2
#     email user 2 = "Luluk@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
emailuser2 = "Luluk@gmail.com"

print(emailuser2)
# Out:
# Luluk@gmail.com

# %%
#tidak boleh didahului oleh angka
3_email_user = "Lulukrifah@gmail.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-596775447.py", line 2
#     3_email_user = "Lulukrifah@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 = "Lulukrifah@gmail.com"

print(email_user_3)
# Out:
# Lulukrifah@gmail.com

# %%
#tidak boleh menggunakan kata kunci python

# %% [markdown]
# #Tipe Variabel

# %%
usia = 8

print(usia)
type(usia)
# Out:
# 8
# int

# %%
berat_badan = 72.5

type(berat_badan)
# Out:
# float

# %%
nama = "Luluk"

type(nama)
# Out:
# str

# %%
lulus = True

type(lulus)
# Out:
# bool

# %%
titik_koordinat = -5
type(titik_koordinat)
# Out:
# int

# %%
titik_koordinat_bintang = -10.0
type(titik_koordinat_bintang)
# Out:
# float

# %% [markdown]
# #Konversi Tipe Data

# %%
usia = 7

print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = float(usia)
print(usia)
type(usia)
# Out:
# 7.0
# float

# %%
berat_badan = 72.5
print(berat_badan)
type(berat_badan)
# Out:
# 72.5
# float

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = str(usia)
print(usia)
type(usia)
# Out:
# 7
# str

# %%
lulus = 1
print(usia)
type(usia)
# Out:
# 7
# str

# %%
lulus = bool(lulus)
print
